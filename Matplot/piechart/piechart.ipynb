# %% [markdown]
# '''
#     @Author: v sanjay kumar<br>
#     @Date: 2024-08-12 06:00:30<br>
#     @Last Modified by: v sanjay kumar<br>
#     @Last Modified time: 2024-08-12 06:00:30.<br>
#     @Title :programs of piechart<br>
#
# '''

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 1. Write a Python programming to create a pie chart of the popularity of programming
# Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
def Pie_plot(programming_language,popularity):
    '''
    function take the programming_language and popularity list and print pie chart
    parameters list,list-programming_language,popularity
    Return-None
    '''
    plt.figure(figsize=(10,10))
    plt.pie(popularity,labels=programming_language)
    plt.legend()
    plt.show()
    

def main():
    programming_language=[ 'Java','Python', 'PHP', 'JavaScript', 'C#', 'C++']
    Popularity=[22.2, 17.6, 8.8, 8, 7.7, 6.7]
    Pie_plot(programming_language,Popularity)

# %% [markdown]
# 2. Write a Python programming to create a pie chart with a title of the popularity of programming
# Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
def Pie_plot(programming_language,popularity):
    '''
    function take the programming_language and popularity list and print pie chart

    parameters list,list-programming_language,popularity

    Return-None
    '''
    plt.figure(figsize=(8,8))
    plt.pie(popularity,labels=programming_language)
    plt.title(' The Popularity Of Programming Languages')
    plt.legend()
    plt.show()
    

def main():
    programming_language=[ 'Java','Python', 'PHP', 'JavaScript', 'C#', 'C++']
    Popularity=[22.2, 17.6, 8.8, 8, 7.7, 6.7]
    Pie_plot(programming_language,Popularity)


if __name__ == '__main__':
    main()

# %% [markdown]
# 3. Write a Python programming to create a pie chart of gold medal achievements of five most
# successful countries in 2016 Summer Olympics. Read the data from a csv file.

# %%
def Csv_chart(countries, gold_medals):
    '''
    Function to create a pie chart of gold medal achievements of five most
    successful countries in 2016 Summer Olympics. Read the data from a csv file.

    Parameters:
    countries (list): List of country names.
    gold_medals (list): List of gold medals won by each country.

    Returns:
    None
    '''
    plt.figure(figsize=(10, 7))
    plt.pie(gold_medals, labels=countries, autopct='%1.1f%%', startangle=140)
    plt.title('Gold Medal Achievements of Top 5 Countries in 2016 Summer Olympics')
    plt.axis('equal')  
    plt.show()

def main():
    try:
        data = pd.read_csv('piedata.csv')
        if data.empty:
            raise ValueError("CSV file is empty")
        
        countries = data['country'].tolist()
        gold_medals = data['gold_medal'].tolist()
        
        Csv_chart(countries, gold_medals)
    except FileNotFoundError:
        print("The file 'piedata.csv' was not found.")
    except pd.errors.EmptyDataError:
        print("No columns to parse from file. The file might be empty.")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == '__main__':
    main()
# Out:
#          country  gold_medal
# 0  United States          46
# 1  Great Britain          27
# 2          China          26
# 3         Russia          19
