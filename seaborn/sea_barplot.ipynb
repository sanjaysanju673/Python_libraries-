# %% [markdown]
# '''
#     @Author: v sanjay kumar<br>
#     @Date: 2024-08-12 06:00:30<br>
#     @Last Modified by: v sanjay kumar<br>
#     @Last Modified time: 2024-08-12 06:00:30.<br>
#     @Title :program to draw bar plot of sex against survived for a dataset given in the titanic.<br>
# '''

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 1. Write a program to draw bar plot of sex against survived for a dataset given in the url.

# %%
def plot_data(url):
    df =pd.read_csv(url)

    sns.countplot(x='sex', hue='survived', data=df)

    plt.xlabel('Sex')
    plt.ylabel('Count')
    plt.title('Survival Count by Sex')

    plt.show()
def main():
    try:
        url='https://github.com/mwaskom/seaborn-data/raw/master/titanic.csv'
        plot_data(url)

    except Exception as e:
        print('Invalid Input',e)

if __name__ == '__main__':
    main()
